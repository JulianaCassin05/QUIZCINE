# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianaCassin05/QUIZCINE/blob/main/PipelineIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('SDW2023.csv.txt')
user_ids = df['UserID'].tolist()
print(user_ids)
# Out:
# [3946, 3947, 3948]

# %%
import requests
import json

sdw2023_api_url = 'https://sdw-2023-prd.up.railway.app'

def get_user(id):
  response = requests.get(f'{sdw2023_api_url}/users/{id}')
  return response.json() if response.status_code == 200 else None

users = [user for id in user_ids if (user := get_user(id)) is not None]
print(json.dumps(users, indent=2))
# Out:
# [
#   {
#     "id": 3946,
#     "name": "calum",
#     "account": {
#       "id": 4174,
#       "number": "00356-2",
#       "agency": "0003",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 3837,
#       "number": "2391 6723 1234 2969",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": []
#   },
#   {
#     "id": 3947,
#     "name": "billy",
#     "account": {
#       "id": 4175,
#       "number": "0582-2",
#       "agency": "0001",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 3838,
#       "number": "2991 6763 1204 2979",
#       "limit": 1000.0
#     },
#     "features": [],
#     "news": []
#   },
#   {
#     "id": 3948,
#     "name": "stu",
#     "account": {
#       "id": 4176,
#       "number": "0102-2",
#       "agency": "0006",
#       "balance": 0.0,
#       "limit": 500.0
#     },
#     "card": {
#       "id": 3839,
#       "number": "2001 6003 1204 1979",
# ...

# %%
openai_api_key = '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'
import openai

openai.api_key = openai_api_key

def generate_ai_news(user):
  completion = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
      {
          "role": "system",
          "content": "Você é um especialista em markting bancário."
      },
      {
          "role": "user",
          "content": f"Crie uma mensagem para {user['name']} sobre a importância dos investimentos (máximo de 100 caracteres)"
      }
    ]
  )
  return completion.choices[0].message.content.strip('\"')

for user in users:
  news = generate_ai_news(user)
  print(news)
  user['news'].append({
      "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
      "description": news
  })
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-25-947d96c6104a> in <cell line: 22>()
#      21
#      22 for user in users:
# ---> 23   news = generate_ai_news(user)
#      24   print(news)
#      25   user['news'].append({
#
# <ipython-input-25-947d96c6104a> in generate_ai_news(user)
#       5
#       6 def generate_ai_news(user):
# ----> 7   completion = openai.ChatCompletion.create(
#       8     model="gpt-4",
#       9     messages=[
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ...

# %%
def update_user(user):
  response = requests.put(f"{sdw2023_api_url}/users/{user['id']}", json=user)
  return True if response.status_code == 200 else False

for user in users:
  success = update_user(user)
  print(f"User {user['name']} updated? {success}!")
# Out:
# User calum updated? True!
# User billy updated? True!
# User stu updated? True!
